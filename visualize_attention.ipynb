# %%
import torch
import matplotlib.pyplot as plt

attn = torch.load("results/attention_weights.pt")

# Take first head
head = attn[0, 0].detach().numpy()

plt.imshow(head, cmap="viridis")
plt.colorbar()
plt.title("Self-Attention Heatmap")
plt.xlabel("Key Tokens")
plt.ylabel("Query Tokens")
plt.show()
